# %%
# SESSION 1
print("Hello World")

a = 10
b = 4

print(a+b)
# print(c)
# Out:
# Hello World
# 14

# %% [markdown]
# # Session 1
# ### computer vision
#
# - a
# - b
# - c
#
# this is a test

# %%
import numpy as np
import cv2

# %%
image = cv2.imread("Lucy.jpg")

# %%
print(image)
# Out:
# [[[217 218 216]
#   [217 218 216]
#   [217 218 216]
#   ...
#   [167 173 178]
#   [166 172 177]
#   [165 171 176]]
#
#  [[217 218 216]
#   [217 218 216]
#   [217 218 216]
#   ...
#   [167 173 178]
#   [166 172 177]
#   [165 171 176]]
#
#  [[216 217 215]
#   [216 217 215]
#   [216 217 215]
#   ...
#   [167 173 178]
#   [166 172 177]
#   [165 171 176]]
#
#  ...
#
#  [[206 210 211]
#   [204 208 209]
#   [200 204 205]
#   ...
#   [167 173 180]
#   [167 173 180]
#   [167 173 180]]
#
#  [[203 207 208]
#   [201 205 206]
#   [198 202 203]
#   ...
#   [167 173 180]
#   [167 173 180]
#   [166 172 179]]
#
#  [[202 206 207]
#   [200 204 205]
#   [196 200 201]
#   ...
#   [167 173 180]
#   [167 173 180]
#   [167 173 180]]]

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.dtype
# Out:
# dtype('uint8')

# %%
image.shape
# Out:
# (598, 960, 3)

# %%
image.max()
# Out:
# np.uint8(255)

# %%
print(image.min())
# Out:
# 0

# %%
image.min()
# Out:
# np.uint8(0)

# %%
[1,2 , 5, 9]
[1, 2, 3, 4]

def func(a, b):
    pass

def func2(a, func):
    pass

# %%
cv2.imshow('name', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image[:, :, 0].shape
# Out:
# (598, 960)

# %%
image[:, :, 1].shape
# Out:
# (598, 960)
