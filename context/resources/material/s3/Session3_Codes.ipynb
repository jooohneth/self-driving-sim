# %%
import numpy as np
import cv2

# %%
cat2= cv2.imread("cat2.jpg") 
cat2.shape
# Out:
# (225, 225, 3)

# %%
cv2.imshow('frame', cat2)
cv2.waitKey(100)
cv2.destroyAllWindows()

# %%
lucy

# %%
hsv = cv2.cvtColor(lucy, cv2.COLOR_BGR2HSV)

# %%
cv2.imshow('frame', hsv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('hsv.png', hsv)

# %%
image1 = cv2.imread("../Lucy.jpg")
image2 = cv2.imread("../Lucy.jpg")

# %%
temp = image1
type(temp)

# %%
temp.dtype

# %%
temp[0:100, 100:300] = 0

# %%
cv2.imshow('temp', temp)
cv2.imshow('image1', image1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
temp2 = image2.copy()
temp2[0:100, 100:300] = 0

# %%
cv2.imshow('temp2', temp2)
cv2.imshow('image1', image2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from copy import deepcopy

# %%
image1[:, :, 2].max()

# %%
image1.shape

# %%
cv2.imshow('temp', image1[100:300, 500:800])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image1[0:200, 100:400] = image1[100:300, 500:800]
cv2.imshow('temp', image1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
arr_ = np.array([1, 2, 3]) * 3

# %%
b, g, r = cv2.split(image1)

# %%
b

# %%
rgb_image = cv2.merge((r, g, b))

# %%
cv2.imshow('temp', rgb_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow('temp', image1[:, :, 0])
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image1[:, :, 1] = 0
image1[:, :, 2] = 0
cv2.imshow('temp', image1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
new_image = np.zeros(image1.shape, dtype='uint8')
new_image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 new_image = np.zeros(image1.shape, dtype='uint8')
#       2 new_image
#
# NameError: name 'image1' is not defined

# %%
new_img = np.zeros_like(image1, dtype='uint8')

# %%
new_img[:, :, 0] = image1[:, :, 0]

# %%
cv2.imshow('temp', new_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.copyMakeBorder()

# %%
def func_(a: int, b: float) -> list[int]:
    pass
